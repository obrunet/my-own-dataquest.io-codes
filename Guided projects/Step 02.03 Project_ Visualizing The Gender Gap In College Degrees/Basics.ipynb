# %% [markdown]
# # Visualizing The Gender Gap In College Degrees

# %% [markdown]
# - We will generate line charts to compare across all degree categories.
# - We'll explore how to export the final diagram we create as an image file.

# %% [markdown]
# ### Data set and visualization created with only STEM degrees

# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt

women_degrees = pd.read_csv('percent-bachelors-degrees-women-usa.csv')
cb_dark_blue = (0/255,107/255,164/255)
cb_orange = (255/255, 128/255, 14/255)
stem_cats = ['Engineering', 'Computer Science', 'Psychology', 'Biology', 'Physical Sciences', 'Math and Statistics']

fig = plt.figure(figsize=(18, 3))

for sp in range(0,6):
    ax = fig.add_subplot(1,6,sp+1)
    ax.plot(women_degrees['Year'], women_degrees[stem_cats[sp]], c=cb_dark_blue, label='Women', linewidth=3)
    ax.plot(women_degrees['Year'], 100-women_degrees[stem_cats[sp]], c=cb_orange, label='Men', linewidth=3)
    ax.spines["right"].set_visible(False)    
    ax.spines["left"].set_visible(False)
    ax.spines["top"].set_visible(False)    
    ax.spines["bottom"].set_visible(False)
    ax.set_xlim(1968, 2011)
    ax.set_ylim(0,100)
    ax.set_title(stem_cats[sp])
    ax.tick_params(bottom="off", top="off", left="off", right="off")
    
    if sp == 0:
        ax.text(2005, 87, 'Men')
        ax.text(2002, 8, 'Women')
    elif sp == 5:
        ax.text(2005, 62, 'Men')
        ax.text(2001, 35, 'Women')
plt.show()

# %% [markdown]
# ### Degrees grouped into STEM, liberal arts, and other:

# %%
stem_cats = ['Psychology', 'Biology', 'Math and Statistics', 'Physical Sciences', 'Computer Science', 'Engineering']
lib_arts_cats = ['Foreign Languages', 'English', 'Communications and Journalism', 'Art and Performance', 'Social Sciences and History']
other_cats = ['Health Professions', 'Public Administration', 'Education', 'Agriculture','Business', 'Architecture']

# %% [markdown]
# Generate a 6 row by 3 column grid of subplots. Lists are ordered in descending order by the percentage of degrees awarded to women.

# %%
fig = plt.figure(figsize=(20, 20))
#------------------------------------------------------------------- 

# FIRST COLUMN: STEM DEGREES
for sp in range(0,18,3):
    
    # index for the first in three subplots 
    i = int(sp/3) 
    # add subplot: 6 row by 3 col.
    ax = fig.add_subplot(6,3,sp+1)
    # for the STEM degrees:
    ax.plot(women_degrees['Year'], women_degrees[stem_cats[i]], c=cb_dark_blue, label='Women', linewidth=3)
    ax.plot(women_degrees['Year'], 100-women_degrees[stem_cats[i]], c=cb_orange, label='Men', linewidth=3)
    ax.set_title(stem_cats[i]) # <-- set title: STEM degrees
    
    # Unchanged code
    for key,spine in ax.spines.items():
        spine.set_visible(False)
    ax.set_xlim(1968, 2011)
    ax.set_ylim(0,100)
    ax.tick_params(bottom="off", top="off", left="off", right="off")
    if i == 0:
        ax.text(2003, 85, 'Women')
        ax.text(2005, 10, 'Men')
    elif i == 5:
        ax.text(2005, 87, 'Men')
        ax.text(2003, 7, 'Women')
#-------------------------------------------------------------------

# SECOND COLUMN: LIB ARTS DEGREES
for sp in range(1,16,3):   # +1: range from 1 to 3x5 (only 5 cats)
    
    # index for the second in three subplots 
    i = int((sp-1)/3) 
    # add subplot: 6 row by 3 col.
    ax = fig.add_subplot(6,3,sp+1)
    # for the lib_arts_cats:
    ax.plot(women_degrees['Year'], women_degrees[lib_arts_cats[i]], c=cb_dark_blue, label='Women', linewidth=3)
    ax.plot(women_degrees['Year'], 100-women_degrees[lib_arts_cats[i]], c=cb_orange, label='Men', linewidth=3)
    ax.set_title(lib_arts_cats[i]) # <-- set title: lib art degrees
    
    # Unchanged code
    for key,spine in ax.spines.items():
        spine.set_visible(False)
    ax.set_xlim(1968, 2011)
    ax.set_ylim(0,100)
    ax.tick_params(bottom="off", top="off", left="off", right="off")
    if i == 0:
        ax.text(2003, 85, 'Women')
        ax.text(2005, 10, 'Men')
    # no case for i == 5 because only 5 cats
#-------------------------------------------------------------------

# THIRD COLUMN: OTHER DEGREES 
for sp in range(2,20,3): # +2 with 6 cats)
    
    # index for the third in three subplots 
    i = int((sp-2)/3) 
    # add subplot: 6 row by 3 col.
    ax = fig.add_subplot(6,3,sp+1)
    # for the other degrees:
    ax.plot(women_degrees['Year'], women_degrees[other_cats[i]], c=cb_dark_blue, label='Women', linewidth=3)
    ax.plot(women_degrees['Year'], 100-women_degrees[other_cats[i]], c=cb_orange, label='Men', linewidth=3)
    ax.set_title(other_cats[i]) # <-- set title: other degrees
    
    # Unchanged code
    for key,spine in ax.spines.items():
        spine.set_visible(False)
    ax.set_xlim(1968, 2011)
    ax.set_ylim(0,100)
    ax.tick_params(bottom="off", top="off", left="off", right="off")
    if i == 0:
        ax.text(2003, 85, 'Women')
        ax.text(2005, 10, 'Men')
    elif i == 5:
        ax.text(2005, 87, 'Men')
        ax.text(2003, 7, 'Women')

        
plt.show()

# %% [markdown]
# Disabling the x-axis labels for all line charts except the bottommost line charts in each column

# %%
fig = plt.figure(figsize=(20, 20))
#------------------------------------------------------------------- 

# FIRST COLUMN: STEM DEGREES
for sp in range(0,18,3):
    i = int(sp/3) 
    ax = fig.add_subplot(6,3,sp+1)
    ax.plot(women_degrees['Year'], women_degrees[stem_cats[i]], c=cb_dark_blue, label='Women', linewidth=3)
    ax.plot(women_degrees['Year'], 100-women_degrees[stem_cats[i]], c=cb_orange, label='Men', linewidth=3)
    ax.set_title(stem_cats[i])
    for key,spine in ax.spines.items():
        spine.set_visible(False)
    ax.set_xlim(1968, 2011)
    ax.set_ylim(0,100)
    # --- change here ---
    ax.tick_params(bottom="off", top="off", left="off", right="off", labelbottom='off')
    if i == 0:
        ax.text(2003, 85, 'Women')
        ax.text(2005, 10, 'Men')
    elif i == 5:
        ax.text(2005, 87, 'Men')
        ax.text(2003, 7, 'Women')
        # --- change here ---
        ax.tick_params(labelbottom='on')
#-------------------------------------------------------------------

# SECOND COLUMN: LIB ARTS DEGREES
for sp in range(1,16,3):
    i = int((sp-1)/3) 
    ax = fig.add_subplot(6,3,sp+1)
    ax.plot(women_degrees['Year'], women_degrees[lib_arts_cats[i]], c=cb_dark_blue, label='Women', linewidth=3)
    ax.plot(women_degrees['Year'], 100-women_degrees[lib_arts_cats[i]], c=cb_orange, label='Men', linewidth=3)
    ax.set_title(lib_arts_cats[i])
    for key,spine in ax.spines.items():
        spine.set_visible(False)
    ax.set_xlim(1968, 2011)
    ax.set_ylim(0,100)
    # --- change here ---
    ax.tick_params(bottom="off", top="off", left="off", right="off", labelbottom='off')
    if i == 0:
        ax.text(2003, 85, 'Women')
        ax.text(2005, 10, 'Men')
    elif i == 4:
        ax.text(2005, 87, 'Men')
        ax.text(2003, 7, 'Women')
        # --- change here ---
        ax.tick_params(labelbottom='on')
#-------------------------------------------------------------------

# THIRD COLUMN: OTHER DEGREES 
for sp in range(2,20,3): # +2 with 6 cats)
    i = int((sp-2)/3) 
    ax = fig.add_subplot(6,3,sp+1)
    ax.plot(women_degrees['Year'], women_degrees[other_cats[i]], c=cb_dark_blue, label='Women', linewidth=3)
    ax.plot(women_degrees['Year'], 100-women_degrees[other_cats[i]], c=cb_orange, label='Men', linewidth=3)
    ax.set_title(other_cats[i])
    for key,spine in ax.spines.items():
        spine.set_visible(False)
    ax.set_xlim(1968, 2011)
    ax.set_ylim(0,100)
    # --- change here ---
    ax.tick_params(bottom="off", top="off", left="off", right="off", labelbottom='off')
    if i == 0:
        ax.text(2003, 85, 'Women')
        ax.text(2005, 10, 'Men')
    elif i == 5:
        ax.text(2005, 87, 'Men')
        ax.text(2003, 7, 'Women')
        # --- change here ---
        ax.tick_params(labelbottom='on')

        
plt.show()

# %% [markdown]
# Simplifying the y-axis labels: enabling just the labels at 0 and 100

# %%
fig = plt.figure(figsize=(20, 20))
#------------------------------------------------------------------- 

# FIRST COLUMN: STEM DEGREES
for sp in range(0,18,3):
    i = int(sp/3) 
    ax = fig.add_subplot(6,3,sp+1)
    ax.plot(women_degrees['Year'], women_degrees[stem_cats[i]], c=cb_dark_blue, label='Women', linewidth=3)
    ax.plot(women_degrees['Year'], 100-women_degrees[stem_cats[i]], c=cb_orange, label='Men', linewidth=3)
    ax.set_title(stem_cats[i])
    for key,spine in ax.spines.items():
        spine.set_visible(False)
    ax.set_xlim(1968, 2011)
    ax.set_ylim(0,100)
    ax.tick_params(bottom="off", top="off", left="off", right="off", labelbottom='off')
    # --- change here ---
    ax.set_yticks([0,100])
    if i == 0:
        ax.text(2003, 85, 'Women')
        ax.text(2005, 10, 'Men')
    elif i == 5:
        ax.text(2005, 87, 'Men')
        ax.text(2003, 7, 'Women')
        ax.tick_params(labelbottom='on')
#-------------------------------------------------------------------

# SECOND COLUMN: LIB ARTS DEGREES
for sp in range(1,16,3):
    i = int((sp-1)/3) 
    ax = fig.add_subplot(6,3,sp+1)
    ax.plot(women_degrees['Year'], women_degrees[lib_arts_cats[i]], c=cb_dark_blue, label='Women', linewidth=3)
    ax.plot(women_degrees['Year'], 100-women_degrees[lib_arts_cats[i]], c=cb_orange, label='Men', linewidth=3)
    ax.set_title(lib_arts_cats[i])
    for key,spine in ax.spines.items():
        spine.set_visible(False)
    ax.set_xlim(1968, 2011)
    ax.set_ylim(0,100)
    ax.tick_params(bottom="off", top="off", left="off", right="off", labelbottom='off')
    # --- change here ---
    ax.set_yticks([0,100])
    if i == 0:
        ax.text(2003, 85, 'Women')
        ax.text(2005, 10, 'Men')
    elif i == 4:
        ax.text(2005, 87, 'Men')
        ax.text(2003, 7, 'Women')
        ax.tick_params(labelbottom='on')
#-------------------------------------------------------------------

# THIRD COLUMN: OTHER DEGREES 
for sp in range(2,20,3): # +2 with 6 cats)
    i = int((sp-2)/3) 
    ax = fig.add_subplot(6,3,sp+1)
    ax.plot(women_degrees['Year'], women_degrees[other_cats[i]], c=cb_dark_blue, label='Women', linewidth=3)
    ax.plot(women_degrees['Year'], 100-women_degrees[other_cats[i]], c=cb_orange, label='Men', linewidth=3)
    ax.set_title(other_cats[i])
    for key,spine in ax.spines.items():
        spine.set_visible(False)
    ax.set_xlim(1968, 2011)
    ax.set_ylim(0,100)
    ax.tick_params(bottom="off", top="off", left="off", right="off", labelbottom='off')
    # --- change here ---
    ax.set_yticks([0,100])
    if i == 0:
        ax.text(2003, 85, 'Women')
        ax.text(2005, 10, 'Men')
    elif i == 5:
        ax.text(2005, 87, 'Men')
        ax.text(2003, 7, 'Women')
        ax.tick_params(labelbottom='on')

        
plt.show()

# %% [markdown]
# Generating a horizontal line across all of the line charts where the y-axis label 50 would have been.

# %%
fig = plt.figure(figsize=(20, 20))
#------------------------------------------------------------------- 

# FIRST COLUMN: STEM DEGREES
for sp in range(0,18,3):
    i = int(sp/3) 
    ax = fig.add_subplot(6,3,sp+1)
    ax.plot(women_degrees['Year'], women_degrees[stem_cats[i]], c=cb_dark_blue, label='Women', linewidth=3)
    ax.plot(women_degrees['Year'], 100-women_degrees[stem_cats[i]], c=cb_orange, label='Men', linewidth=3)
    ax.set_title(stem_cats[i])
    for key,spine in ax.spines.items():
        spine.set_visible(False)
    ax.set_xlim(1968, 2011)
    ax.set_ylim(0,100)
    ax.tick_params(bottom="off", top="off", left="off", right="off", labelbottom='off')
    ax.set_yticks([0,100])
    ax.axhline(50, c=(171/255, 171/255, 171/255), alpha=0.3) # <-- change here
    if i == 0:
        ax.text(2003, 85, 'Women')
        ax.text(2005, 10, 'Men')
    elif i == 5:
        ax.text(2005, 87, 'Men')
        ax.text(2003, 7, 'Women')
        ax.tick_params(labelbottom='on')
#-------------------------------------------------------------------

# SECOND COLUMN: LIB ARTS DEGREES
for sp in range(1,16,3):
    i = int((sp-1)/3) 
    ax = fig.add_subplot(6,3,sp+1)
    ax.plot(women_degrees['Year'], women_degrees[lib_arts_cats[i]], c=cb_dark_blue, label='Women', linewidth=3)
    ax.plot(women_degrees['Year'], 100-women_degrees[lib_arts_cats[i]], c=cb_orange, label='Men', linewidth=3)
    ax.set_title(lib_arts_cats[i])
    for key,spine in ax.spines.items():
        spine.set_visible(False)
    ax.set_xlim(1968, 2011)
    ax.set_ylim(0,100)
    ax.tick_params(bottom="off", top="off", left="off", right="off", labelbottom='off')
    ax.set_yticks([0,100])
    ax.axhline(50, c=(171/255, 171/255, 171/255), alpha=0.3) # <-- change here
    if i == 0:
        ax.text(2003, 85, 'Women')
        ax.text(2005, 10, 'Men')
    elif i == 4:
        ax.text(2005, 87, 'Men')
        ax.text(2003, 7, 'Women')
        ax.tick_params(labelbottom='on')
#-------------------------------------------------------------------

# THIRD COLUMN: OTHER DEGREES 
for sp in range(2,20,3):
    i = int((sp-2)/3) 
    ax = fig.add_subplot(6,3,sp+1)
    ax.plot(women_degrees['Year'], women_degrees[other_cats[i]], c=cb_dark_blue, label='Women', linewidth=3)
    ax.plot(women_degrees['Year'], 100-women_degrees[other_cats[i]], c=cb_orange, label='Men', linewidth=3)
    ax.set_title(other_cats[i])
    for key,spine in ax.spines.items():
        spine.set_visible(False)
    ax.set_xlim(1968, 2011)
    ax.set_ylim(0,100)
    ax.tick_params(bottom="off", top="off", left="off", right="off", labelbottom='off')
    ax.set_yticks([0,100])
    ax.axhline(50, c=(171/255, 171/255, 171/255), alpha=0.3) # <-- change here
    if i == 0:
        ax.text(2003, 85, 'Women')
        ax.text(2005, 10, 'Men')
    elif i == 5:
        ax.text(2005, 87, 'Men')
        ax.text(2003, 7, 'Women')
        ax.tick_params(labelbottom='on')

        
plt.show()

# %% [markdown]
# ## Exporting the created plots using matplotlib
# ##### Allows us to use them in Word documents, Powerpoint presentations, and even in emails.

# %% [markdown]
# With the current backend we're using, we can use Figure.savefig() or pyplot.savefig() to export all of the plots contained in the figure as a single image file. Note that these have to be called before we display the figure using pyplot.show().:
#
# ax.set_yticks([0,100])
# plt.plot(women_degrees['Year'], women_degrees['Biology'])
# plt.savefig('biology_degrees.png')
#
# A line chart is saved as a PNG file. The image will be exported into the same folder that your Jupyter Notebook server is running.

# %%
fig = plt.figure(figsize=(20, 20))
#------------------------------------------------------------------- 

# FIRST COLUMN: STEM DEGREES
for sp in range(0,18,3):
    i = int(sp/3) 
    ax = fig.add_subplot(6,3,sp+1)
    ax.plot(women_degrees['Year'], women_degrees[stem_cats[i]], c=cb_dark_blue, label='Women', linewidth=3)
    ax.plot(women_degrees['Year'], 100-women_degrees[stem_cats[i]], c=cb_orange, label='Men', linewidth=3)
    ax.set_title(stem_cats[i])
    for key,spine in ax.spines.items():
        spine.set_visible(False)
    ax.set_xlim(1968, 2011)
    ax.set_ylim(0,100)
    ax.tick_params(bottom="off", top="off", left="off", right="off", labelbottom='off')
    ax.set_yticks([0,100])
    ax.axhline(50, c=(171/255, 171/255, 171/255), alpha=0.3) # <-- change here
    if i == 0:
        ax.text(2003, 85, 'Women')
        ax.text(2005, 10, 'Men')
    elif i == 5:
        ax.text(2005, 87, 'Men')
        ax.text(2003, 7, 'Women')
        ax.tick_params(labelbottom='on')
#-------------------------------------------------------------------

# SECOND COLUMN: LIB ARTS DEGREES
for sp in range(1,16,3):
    i = int((sp-1)/3) 
    ax = fig.add_subplot(6,3,sp+1)
    ax.plot(women_degrees['Year'], women_degrees[lib_arts_cats[i]], c=cb_dark_blue, label='Women', linewidth=3)
    ax.plot(women_degrees['Year'], 100-women_degrees[lib_arts_cats[i]], c=cb_orange, label='Men', linewidth=3)
    ax.set_title(lib_arts_cats[i])
    for key,spine in ax.spines.items():
        spine.set_visible(False)
    ax.set_xlim(1968, 2011)
    ax.set_ylim(0,100)
    ax.tick_params(bottom="off", top="off", left="off", right="off", labelbottom='off')
    ax.set_yticks([0,100])
    ax.axhline(50, c=(171/255, 171/255, 171/255), alpha=0.3) # <-- change here
    if i == 0:
        ax.text(2003, 85, 'Women')
        ax.text(2005, 10, 'Men')
    elif i == 4:
        ax.text(2005, 87, 'Men')
        ax.text(2003, 7, 'Women')
        ax.tick_params(labelbottom='on')
#-------------------------------------------------------------------

# THIRD COLUMN: OTHER DEGREES 
for sp in range(2,20,3):
    i = int((sp-2)/3) 
    ax = fig.add_subplot(6,3,sp+1)
    ax.plot(women_degrees['Year'], women_degrees[other_cats[i]], c=cb_dark_blue, label='Women', linewidth=3)
    ax.plot(women_degrees['Year'], 100-women_degrees[other_cats[i]], c=cb_orange, label='Men', linewidth=3)
    ax.set_title(other_cats[i])
    for key,spine in ax.spines.items():
        spine.set_visible(False)
    ax.set_xlim(1968, 2011)
    ax.set_ylim(0,100)
    ax.tick_params(bottom="off", top="off", left="off", right="off", labelbottom='off')
    ax.set_yticks([0,100])
    ax.axhline(50, c=(171/255, 171/255, 171/255), alpha=0.3) 
    if i == 0:
        ax.text(2003, 85, 'Women')
        ax.text(2005, 10, 'Men')
    elif i == 5:
        ax.text(2005, 87, 'Men')
        ax.text(2003, 7, 'Women')
        ax.tick_params(labelbottom='on')

# --- change here ---        
plt.show()
